# %% [markdown]
# # Exploratory Data Analysis

# %%
# Importing pandas library


import pandas as pd

# %%
data = pd.read_csv('Pokemon.csv')

data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#first 50 entries of data

data.head(50)
# Out:
#      #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0    1                  Bulbasaur     Grass  Poison    318   45      49
# 1    2                    Ivysaur     Grass  Poison    405   60      62
# 2    3                   Venusaur     Grass  Poison    525   80      82
# 3    3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4    4                 Charmander      Fire     NaN    309   39      52
# 5    5                 Charmeleon      Fire     NaN    405   58      64
# 6    6                  Charizard      Fire  Flying    534   78      84
# 7    6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8    6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9    7                   Squirtle     Water     NaN    314   44      48
# 10   8                  Wartortle     Water     NaN    405   59      63
# 11   9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
# last 5 entries of data

data.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# # reading columns

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# reading individual columns

# %%
print(data['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# reading multiple columns

data[['Name','Type 1','Defense']].head()
# Out:
#                     Name Type 1  Defense
# 0              Bulbasaur  Grass       49
# 1                Ivysaur  Grass       63
# 2               Venusaur  Grass       83
# 3  VenusaurMega Venusaur  Grass      123
# 4             Charmander   Fire       43

# %% [markdown]
# # reading rows

# %%
data.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
data.iloc[1:9]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# ...

# %%
data.iloc[1:5, 0:3]
# Out:
#    #                   Name Type 1
# 1  2                Ivysaur  Grass
# 2  3               Venusaur  Grass
# 3  3  VenusaurMega Venusaur  Grass
# 4  4             Charmander   Fire

# %%
data.iloc[1,9]
# Out:
# 80

# %%
data.loc[data['Type 1'] == 'Fire'].head()
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
# describing Data

data.describe()

# %%
data.sort_values('Type 1', ascending = True)
# Out:
#        #      Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 600  540  Sewaddle    Bug     Grass    310   45      53       70       40
# 136  127    Pinsir    Bug       NaN    500   65     125      100       55
# 457  412     Burmy    Bug       NaN    224   40      29       45       29
# 132  123   Scyther    Bug    Flying    500   70     110       80       55
# 656  595    Joltik    Bug  Electric    319   50      47       50       57
# ..   ...       ...    ...       ...    ...  ...     ...      ...      ...
# 172  158  Totodile  Water       NaN    314   50      65       64       44
# 610  550  Basculin  Water       NaN    460   70      92       65       80
# 145  134  Vaporeon  Water       NaN    525  130      65       60      110
# 574  515   Panpour  Water       NaN    316   50      53       48       53
# 184  170  Chinchou  Water  Electric    330   75      38       38       56
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
data.sort_values('Total', ascending = True)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 206  191                Sunkern    Grass       NaN    180   30      30
# 322  298                Azurill   Normal     Fairy    190   50      20
# 446  401              Kricketot      Bug       NaN    194   37      25
# 288  265                Wurmple      Bug       NaN    195   45      45
# 16    13                 Weedle      Bug    Poison    195   40      35
# ..   ...                    ...      ...       ...    ...  ...     ...
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
data.sort_values(['Type 1','Name','Generation',''], ascending = [1,1,1])
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 678  617               Accelgor    Bug     NaN    495   80      70       40
# 182  168                Ariados    Bug  Poison    390   70      90       70
# 290  267              Beautifly    Bug  Flying    395   60      70       50
# 18    15               Beedrill    Bug  Poison    395   65      90       40
# 19    15  BeedrillMega Beedrill    Bug  Poison    495   65     150       40
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 351  321                Wailord  Water     NaN    500  170      90       45
# 10     8              Wartortle  Water     NaN    405   59      63       80
# 372  340               Whiscash  Water  Ground    468  110      78       73
# 301  278                Wingull  Water  Flying    270   40      30       30
# 209  194                 Wooper  Water  Ground    210   55      45       45
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # filtering data

# %%
# let's at the data

data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # 1. how many types of pokemons are there in the data and their values?

# %%
data['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# # 2. extract the data of Fire type pokemons

# %%
data.loc[data['Type 1'] == 'Fire'].head()
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %% [markdown]
# # 3. extract the data of Fire or Water or Poison and Normal type pokemons

# %%
data.loc[(data['Type 1'] == 'Fire') | (data['Type 1'] == 'Water') | (data['Type 1'] == 'Poison') & (data['Type 1'] == 'Normal')]
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander   Fire     NaN    309  39      52
# 5      5                 Charmeleon   Fire     NaN    405  58      64
# 6      6                  Charizard   Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y   Fire  Flying    634  78     104
# ..   ...                        ...    ...     ...    ...  ..     ...
# 735  667                     Litleo   Fire  Normal    369  62      50
# 736  668                     Pyroar   Fire  Normal    507  86      68
# 762  692                  Clauncher  Water     NaN    330  50      53
# 763  693                  Clawitzer  Water     NaN    500  71      73
# 799  721                  Volcanion   Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         43       60       50     65           1      False
# ...

# %% [markdown]
# # 4. Find out how many Grass type pokemons are in the data whose name ends with 'ysaur'.

# %%
data.loc[(data['Type 1'] == 'Grass') & (data['Name'].str.endswith('ysaur'))]
# Out:
#    #     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1  2  Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary
# 1     60           1      False

# %% [markdown]
# #  5. display the pokemons whose defense is greater than 100.

# %%
data[data['Defense'] > 100]
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur   Grass  Poison    625   80     100
# 7      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 12     9    BlastoiseMega Blastoise   Water     NaN    630   79     103
# 33    28                  Sandslash  Ground     NaN    450   75     100
# 81    75                   Graveler    Rock  Ground    390   55      95
# ..   ...                        ...     ...     ...    ...  ...     ...
# 789  713                    Avalugg     Ice     NaN    514   95     117
# 794  718           Zygarde50% Forme  Dragon  Ground    600  108     100
# 795  719                    Diancie    Rock   Fairy    600   50     100
# 796  719        DiancieMega Diancie    Rock   Fairy    700   50     160
# 799  721                  Volcanion    Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # 6. display the pokemons with HP of greater than 76 and are of water type.

# %%
data[(data['HP'] > 76) & (data['Type 1'] == 'Water')].head(30)
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 11     9                Blastoise  Water       NaN    530   79      83
# 12     9  BlastoiseMega Blastoise  Water       NaN    630   79     103
# 60    55                  Golduck  Water       NaN    500   80      82
# 67    62                Poliwrath  Water  Fighting    510   90      95
# 79    73               Tentacruel  Water    Poison    515   80      70
# 85    79                 Slowpoke  Water   Psychic    315   90      65
# 86    80                  Slowbro  Water   Psychic    490   95      75
# 87    80      SlowbroMega Slowbro  Water   Psychic    590   95      75
# 94    87                  Dewgong  Water       Ice    475   90      70
# 128  119                  Seaking  Water       NaN    450   80      92
# 140  130                 Gyarados  Water    Flying    540   95     125
# 141  130    GyaradosMega Gyarados  Water      Dark    640   95     155
# ...

# %% [markdown]
# # 7. find out the average Speed

# %%
data['Speed'].mean()
# Out:
# 68.2775

# %% [markdown]
# # 8. display total statistics for each type 1

# %%
i = 'Type 1'

for i, df  in data.groupby(['Type 1']):
    print("Type 1-",i)
    print(df['Total'].describe())
    print(df['Total'].describe().count())
# Out:
# Type 1- Bug
# count     69.000000
# mean     378.927536
# std      117.875223
# min      194.000000
# 25%      269.000000
# 50%      395.000000
# 75%      475.000000
# max      600.000000
# Name: Total, dtype: float64
# 8
# Type 1- Dark
# count     31.000000
# mean     445.741935
# std      109.126217
# min      220.000000
# 25%      359.000000
# 50%      465.000000
# 75%      510.000000
# max      680.000000
# Name: Total, dtype: float64
# 8
# Type 1- Dragon
# count     32.000000
# mean     550.531250
# std      146.267538
# min      300.000000
# 25%      420.000000
# 50%      600.000000
# 75%      680.000000
# max      780.000000
# Name: Total, dtype: float64
# 8
# Type 1- Electric
# count     44.000000
# mean     443.409091
# std      105.721952
# min      205.000000
# 25%      362.250000
# 50%      477.500000
# 75%      520.000000
# max      610.000000
# Name: Total, dtype: float64
# 8
# Type 1- Fairy
# count     17.000000
# mean     413.176471
# std      123.781680
# ...

# %% [markdown]
# # 9. Change legendary value to true for pokemons having total greater than 700

# %%
data.loc[data['Total'] > 700, 'Legendary'] = 'superior'
data.loc[data['Legendary'] == 'superior']
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 552  493                 Arceus   Normal       NaN    720  120     120
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary
# 163      100      154      100    130           1  superior
# 164       70      194      120    140           1  superior
# 422       90      180      160     90           3  superior
# 424      160      150       90     90           3  superior
# 426      100      180      100    115           3  superior
# 552      120      120      120    120           4  superior

# %% [markdown]
# # 10. count type 1 pokemons and use groupby func.

# %%
data.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...
